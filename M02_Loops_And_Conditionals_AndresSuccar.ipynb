# %%
# Module Assignment

#Student: Andres Succar  
#Description: Conditional statements and loops in Python

# %%
#4.1

secret = 7
guess = 5

if guess < secret:
    print("too low")
elif guess > secret:
    print("too high")
else:
    print("just right")
# Out:
# too low

# %%
# 4.2

small = True
green = True

if small and green:
    print("pea")
elif small and not green:
    print("blackberry")
else:
    print("Guanábana")
# Out:
# pea

# %%
# 6.1 

for number in [3, 2, 1, 0]:
    print(number)
# Out:
# 3
# 2
# 1
# 0

# %%
# 6.2

guess_me = 7
number = 1

while True:
    if number < guess_me:
        print("too low")
    elif number == guess_me:
        print("found it!")
        break
    else:
        print("oops")
        break

    number += 1
# Out:
# too low
# too low
# too low
# too low
# too low
# too low
# found it!

# %%
# 6.3

guess_me = 5

for number in range(10):
    if number < guess_me:
        print("too low")
    elif number == guess_me:
        print("found it!")
    else:
        print("oops")
        break
# Out:
# too low
# too low
# too low
# too low
# too low
# found it!
# oops
